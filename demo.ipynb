# %%
# !./bin/001_preprocess.sh exp001_dev
# Out:
# + EXP=exp001_dev
# + PYTHONPATH=.
# + python kaggle_otto2/data_loader/main.py --exp exp001_dev
# [create train_df, test_df, test_labels] start [0.4GB(5.0%)]
# [load] start [0.4GB(5.0%)]
# [load] done [2.8GB(5.0%)(+2.463GB)] 13.7073 s
# [sampling (ratio: 0.05)] start [2.8GB(5.0%)]
# [sampling (ratio: 0.05)] done [3.1GB(5.2%)(+0.323GB)] 3.4440 s
# [create train_df, test_df, test_labels] done [0.9GB(4.1%)(+0.516GB)] 17.2013 s
# [save] start [0.9GB(4.1%)]
# [save] done [0.8GB(4.0%)(-0.081GB)] 1.4215 s
# [create aid idx map] start [0.9GB(4.0%)]
# [create aid idx map] done [1.1GB(4.3%)(+0.194GB)] 12.0115 s
# [create session idx map] start [1.1GB(4.3%)]
# [create session idx map] done [1.1GB(5.0%)(+0.047GB)] 7.7368 s
# [create pair_df] start [0.8GB(4.9%)]
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.03it/s]
# [create pair_df] done [2.3GB(5.3%)(+1.531GB)] 4.3798 s
# pair_df: (28039892, 3)
# [save pair_df] start [2.3GB(5.3%)]
# [save pair_df] done [2.3GB(5.3%)(+0.006GB)] 3.5408 s

# %%
# !./bin/002_candidate_generation.sh exp001_dev
# Out:
# + EXP=exp001_dev
# + PYTHONPATH=.
# + python kaggle_otto2/cand_generator/last_inter/main.py --exp exp001_dev
# [gen_cand_df [inter]] start [0.4GB(2.2%)]
# [gen_cand_df [inter]] done [0.8GB(2.4%)(+0.400GB)] 0.2756 s
# [calc score [last_inter]] start [0.8GB(2.4%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ last_ ┆ 0.324234   ┆ 0.310079   ┆ 0.587156   ┆ 0.47774 ┆ 0.0      ┆ 0.48501 ┆ 0.485658 ┆ 0.485739 ┆ 0.485739 │
# │ inter ┆            ┆            ┆            ┆ 1       ┆          ┆ 2       ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [last_inter]] done [0.9GB(2.5%)(+0.090GB)] 3.3662 s
# [gen_cand_df [buy]] start [0.9GB(2.5%)]
# [gen_cand_df [buy]] done [0.8GB(2.5%)(-0.024GB)] 0.0524 s
# [calc score [last_buy]] start [0.8GB(2.5%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ last_ ┆ 0.044884   ┆ 0.070797   ┆ 0.438915   ┆ 0.28907 ┆ 0.784243 ┆ 0.28993 ┆ 0.289933 ┆ 0.289933 ┆ 0.289933 │
# │ buy   ┆            ┆            ┆            ┆ 6       ┆          ┆ 1       ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [last_buy]] done [0.8GB(2.5%)(-0.022GB)] 2.5553 s
# [gen_cand_df [click]] start [0.8GB(2.5%)]
# [gen_cand_df [click]] done [0.8GB(2.5%)(+0.028GB)] 0.2108 s
# [calc score [last_click]] start [0.8GB(2.5%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ last_ ┆ 0.319426   ┆ 0.301876   ┆ 0.507359   ┆ 0.42692 ┆ 0.001343 ┆ 0.43598 ┆ 0.436612 ┆ 0.436615 ┆ 0.436615 │
# │ click ┆            ┆            ┆            ┆ 1       ┆          ┆ 1       ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [last_click]] done [0.8GB(2.5%)(-0.021GB)] 3.3794 s
# [gen_cand_df [cart]] start [0.8GB(2.5%)]
# [gen_cand_df [cart]] done [0.8GB(2.5%)(-0.022GB)] 0.0554 s
# [calc score [last_cart]] start [0.8GB(2.5%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ last_ ┆ 0.04409    ┆ 0.069976   ┆ 0.437529   ┆ 0.28791 ┆ 0.786466 ┆ 0.28864 ┆ 0.288631 ┆ 0.288631 ┆ 0.288631 │
# │ cart  ┆            ┆            ┆            ┆ 9       ┆          ┆ 9       ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [last_cart]] done [0.8GB(2.5%)(-0.012GB)] 2.5545 s
# [gen_cand_df [order]] start [0.8GB(2.5%)]
# [gen_cand_df [order]] done [0.8GB(2.5%)(-0.002GB)] 0.0228 s
# [calc score [last_order]] start [0.8GB(2.5%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ last_ ┆ 0.00601    ┆ 0.005207   ┆ 0.016435   ┆ 0.01202 ┆ 0.972293 ┆ 0.01200 ┆ 0.012004 ┆ 0.012004 ┆ 0.012004 │
# │ order ┆            ┆            ┆            ┆ 4       ┆          ┆ 5       ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [last_order]] done [0.8GB(2.5%)(-0.011GB)] 2.3676 s
# + PYTHONPATH=.
# + python kaggle_otto2/cand_generator/item_cf/main.py --exp exp001_dev
# [load] start [0.4GB(2.2%)]
# [load] done [1.7GB(2.9%)(+1.286GB)] 4.9871 s
# [get test_aids] start [1.8GB(2.9%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  2.71s/it]
# [get test_aids] done [3.8GB(4.0%)(+2.059GB)] 8.1378 s
# [save cand_df] start [3.8GB(4.0%)]
# [save cand_df] done [3.0GB(3.6%)(-0.866GB)] 3.5562 s
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_sum]] start [1.6GB(3.0%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.455116   ┆ 0.368036   ┆ 0.608871   ┆ 0.52124 ┆ 0.0      ┆ 0.56131 ┆ 0.586515 ┆ 0.606978 ┆ 0.618059 │
# │ cf_s0 ┆            ┆            ┆            ┆ 5       ┆          ┆ 7       ┆          ┆          ┆          │
# │ 12_t0 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ 12_ap ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tdTru ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ e_... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_sum]] done [1.3GB(2.9%)(-0.282GB)] 9.2337 s
# [load] start [1.3GB(2.8%)]
# [load] done [2.3GB(3.4%)(+1.078GB)] 0.9031 s
# [get test_aids] start [2.3GB(3.4%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  3.01s/it]
# [get test_aids] done [3.9GB(4.2%)(+1.527GB)] 9.0213 s
# [save cand_df] start [3.9GB(4.2%)]
# [save cand_df] done [3.0GB(3.7%)(-0.842GB)] 3.4609 s
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_mean]] start [1.7GB(3.1%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.435055   ┆ 0.329018   ┆ 0.485711   ┆ 0.43363 ┆ 0.0      ┆ 0.49004 ┆ 0.532722 ┆ 0.569964 ┆ 0.589194 │
# │ cf_s0 ┆            ┆            ┆            ┆ 7       ┆          ┆ 4       ┆          ┆          ┆          │
# │ 12_t0 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ 12_ap ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tdTru ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ e_... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_mean]] done [1.3GB(2.9%)(-0.357GB)] 9.0874 s
# [load] start [1.2GB(2.8%)]
# [load] done [2.3GB(3.4%)(+1.093GB)] 0.8936 s
# [get test_aids] start [2.3GB(3.4%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  3.13s/it]
# [get test_aids] done [3.8GB(4.4%)(+1.510GB)] 9.3814 s
# [save cand_df] start [3.8GB(4.4%)]
# [save cand_df] done [2.9GB(3.7%)(-0.882GB)] 4.0868 s
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_max]] start [1.6GB(3.0%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.450401   ┆ 0.361973   ┆ 0.580952   ┆ 0.50220 ┆ 0.0      ┆ 0.55218 ┆ 0.581068 ┆ 0.604946 ┆ 0.617104 │
# │ cf_s0 ┆            ┆            ┆            ┆ 3       ┆          ┆ 4       ┆          ┆          ┆          │
# │ 12_t0 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ 12_ap ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tdTru ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ e_... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_max]] done [1.3GB(2.8%)(-0.309GB)] 9.1572 s
# [load] start [1.2GB(2.8%)]
# [load] done [2.3GB(3.3%)(+1.081GB)] 0.8740 s
# [get test_aids] start [2.3GB(3.3%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:04<00:00,  1.67s/it]
# [get test_aids] done [3.4GB(3.8%)(+1.079GB)] 4.9964 s
# [save cand_df] start [3.4GB(3.8%)]
# [save cand_df] done [2.9GB(3.6%)(-0.445GB)] 3.3778 s
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_last]] start [1.7GB(3.0%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.435008   ┆ 0.345317   ┆ 0.495413   ┆ 0.44434 ┆ 0.0      ┆ 0.50102 ┆ 0.537965 ┆ 0.563763 ┆ 0.577153 │
# │ cf_s0 ┆            ┆            ┆            ┆ 4       ┆          ┆ 9       ┆          ┆          ┆          │
# │ 12_t0 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ 12_ap ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tdTru ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ e_... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_last]] done [1.1GB(2.8%)(-0.562GB)] 8.6984 s
# [load] start [1.0GB(2.7%)]
# [load] done [2.1GB(3.3%)(+1.095GB)] 0.8873 s
# [get test_aids] start [2.1GB(3.3%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  3.07s/it]
# [get test_aids] done [4.0GB(4.2%)(+1.872GB)] 9.2211 s
# [save cand_df] start [4.0GB(4.2%)]
# [save cand_df] done [3.2GB(3.8%)(-0.825GB)] 2.8196 s
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_count]] start [1.8GB(3.1%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.215538   ┆ 0.233612   ┆ 0.493037   ┆ 0.38745 ┆ 0.0      ┆ 0.45475 ┆ 0.501386 ┆ 0.556146 ┆ 0.600254 │
# │ cf_s0 ┆            ┆            ┆            ┆ 9       ┆          ┆ 5       ┆          ┆          ┆          │
# │ 12_t0 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ 12_ap ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tdTru ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ e_... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s012_t012_apTrue_tdTrue_trFalse_iifTrue_fFalse_count]] done [1.4GB(2.9%)(-0.429GB)] 8.8136 s
# [load] start [1.3GB(2.8%)]
# [load] done [1.4GB(2.9%)(+0.063GB)] 0.2690 s
# [get test_aids] start [1.4GB(2.9%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  9.86it/s]
# [get test_aids] done [1.3GB(2.8%)(-0.106GB)] 0.3049 s
# [save cand_df] start [1.3GB(2.8%)]
# [save cand_df] done [1.2GB(2.8%)(-0.022GB)] 0.4043 s
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_sum]] start [1.2GB(2.8%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.049213   ┆ 0.089735   ┆ 0.450069   ┆ 0.30188 ┆ 0.784243 ┆ 0.30836 ┆ 0.312063 ┆ 0.315351 ┆ 0.317033 │
# │ cf_s1 ┆            ┆            ┆            ┆ 4       ┆          ┆ 4       ┆          ┆          ┆          │
# │ 2_t12 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _apTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_td ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tr... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_sum]] done [1.2GB(2.8%)(-0.023GB)] 3.0717 s
# [load] start [1.2GB(2.8%)]
# [load] done [1.2GB(2.8%)(+0.052GB)] 0.0850 s
# [get test_aids] start [1.2GB(2.8%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 10.36it/s]
# [get test_aids] done [1.2GB(2.8%)(+0.003GB)] 0.2903 s
# [save cand_df] start [1.2GB(2.8%)]
# [save cand_df] done [1.2GB(2.8%)(-0.012GB)] 0.3907 s
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_mean]] start [1.1GB(2.8%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.047661   ┆ 0.083458   ┆ 0.371659   ┆ 0.25279 ┆ 0.784243 ┆ 0.27848 ┆ 0.295741 ┆ 0.307008 ┆ 0.312989 │
# │ cf_s1 ┆            ┆            ┆            ┆ 9       ┆          ┆ 1       ┆          ┆          ┆          │
# │ 2_t12 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _apTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_td ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tr... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_mean]] done [1.0GB(2.6%)(-0.102GB)] 3.7916 s
# [load] start [1.0GB(2.6%)]
# [load] done [1.1GB(2.6%)(+0.046GB)] 0.0849 s
# [get test_aids] start [1.1GB(2.6%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  9.99it/s]
# [get test_aids] done [1.1GB(2.7%)(+0.050GB)] 0.3013 s
# [save cand_df] start [1.1GB(2.7%)]
# [save cand_df] done [1.1GB(2.7%)(-0.020GB)] 0.3916 s
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_max]] start [1.1GB(2.6%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.048945   ┆ 0.088594   ┆ 0.432711   ┆ 0.29109 ┆ 0.784243 ┆ 0.30406 ┆ 0.310376 ┆ 0.31476  ┆ 0.31664  │
# │ cf_s1 ┆            ┆            ┆            ┆ 9       ┆          ┆ 1       ┆          ┆          ┆          │
# │ 2_t12 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _apTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_td ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tr... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_max]] done [1.0GB(2.6%)(-0.036GB)] 3.0754 s
# [load] start [1.0GB(2.6%)]
# [load] done [1.1GB(2.6%)(+0.058GB)] 0.0850 s
# [get test_aids] start [1.1GB(2.6%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 15.40it/s]
# [get test_aids] done [1.1GB(2.6%)(+0.005GB)] 0.1957 s
# [save cand_df] start [1.1GB(2.6%)]
# [save cand_df] done [1.1GB(2.6%)(-0.022GB)] 0.3499 s
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_last]] start [1.0GB(2.6%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.048245   ┆ 0.08435    ┆ 0.398852   ┆ 0.26944 ┆ 0.784243 ┆ 0.29279 ┆ 0.30114  ┆ 0.306887 ┆ 0.308594 │
# │ cf_s1 ┆            ┆            ┆            ┆         ┆          ┆ 4       ┆          ┆          ┆          │
# │ 2_t12 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _apTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_td ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tr... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_last]] done [1.0GB(2.6%)(-0.048GB)] 2.9030 s
# [load] start [1.0GB(2.6%)]
# [load] done [1.0GB(2.6%)(+0.049GB)] 0.0844 s
# [get test_aids] start [1.0GB(2.6%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 11.11it/s]
# [get test_aids] done [1.2GB(2.7%)(+0.153GB)] 0.2709 s
# [save cand_df] start [1.2GB(2.7%)]
# [save cand_df] done [1.1GB(2.7%)(-0.025GB)] 0.3541 s
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_count]] start [1.1GB(2.6%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.037765   ┆ 0.068122   ┆ 0.403274   ┆ 0.26617 ┆ 0.784243 ┆ 0.28748 ┆ 0.299528 ┆ 0.310309 ┆ 0.315672 │
# │ cf_s1 ┆            ┆            ┆            ┆ 7       ┆          ┆ 3       ┆          ┆          ┆          │
# │ 2_t12 ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _apTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_td ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ True_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ tr... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s12_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_count]] done [1.0GB(2.6%)(-0.044GB)] 3.0600 s
# [load] start [1.0GB(2.6%)]
# [load] done [2.1GB(3.1%)(+1.044GB)] 4.8601 s
# [get test_aids] start [2.1GB(3.1%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  3.18s/it]
# [get test_aids] done [3.8GB(4.0%)(+1.763GB)] 9.5263 s
# [save cand_df] start [3.8GB(4.0%)]
# [save cand_df] done [3.0GB(3.6%)(-0.797GB)] 3.8096 s
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_sum]] start [1.7GB(3.0%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.453879   ┆ 0.356587   ┆ 0.526896   ┆ 0.46850 ┆ 0.001343 ┆ 0.51496 ┆ 0.542177 ┆ 0.567115 ┆ 0.580172 │
# │ cf_s0 ┆            ┆            ┆            ┆ 2       ┆          ┆ 2       ┆          ┆          ┆          │
# │ _t0_a ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ pTrue ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _tdTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_tr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ Fa... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_sum]] done [1.3GB(2.8%)(-0.377GB)] 9.4374 s
# [load] start [1.3GB(2.7%)]
# [load] done [2.3GB(3.2%)(+1.051GB)] 0.8937 s
# [get test_aids] start [2.3GB(3.2%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  3.19s/it]
# [get test_aids] done [3.9GB(4.0%)(+1.570GB)] 9.5716 s
# [save cand_df] start [3.9GB(4.0%)]
# [save cand_df] done [3.1GB(3.6%)(-0.798GB)] 3.6185 s
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_mean]] start [1.8GB(3.0%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.436514   ┆ 0.322848   ┆ 0.428157   ┆ 0.3974  ┆ 0.001343 ┆ 0.45079 ┆ 0.490078 ┆ 0.528349 ┆ 0.549834 │
# │ cf_s0 ┆            ┆            ┆            ┆         ┆          ┆ 9       ┆          ┆          ┆          │
# │ _t0_a ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ pTrue ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _tdTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_tr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ Fa... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_mean]] done [1.3GB(2.8%)(-0.403GB)] 10.2009 s
# [load] start [1.3GB(2.7%)]
# [load] done [2.3GB(3.3%)(+1.056GB)] 0.8825 s
# [get test_aids] start [2.3GB(3.3%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  3.26s/it]
# [get test_aids] done [3.9GB(4.0%)(+1.608GB)] 9.7788 s
# [save cand_df] start [3.9GB(4.0%)]
# [save cand_df] done [3.1GB(3.6%)(-0.805GB)] 3.8512 s
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_max]] start [1.8GB(3.0%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.449935   ┆ 0.350881   ┆ 0.511187   ┆ 0.45697 ┆ 0.001343 ┆ 0.50678 ┆ 0.535839 ┆ 0.5643   ┆ 0.578384 │
# │ cf_s0 ┆            ┆            ┆            ┆         ┆          ┆ 2       ┆          ┆          ┆          │
# │ _t0_a ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ pTrue ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _tdTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_tr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ Fa... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_max]] done [1.4GB(2.8%)(-0.375GB)] 9.5335 s
# [load] start [1.3GB(2.8%)]
# [load] done [2.4GB(3.3%)(+1.056GB)] 0.8798 s
# [get test_aids] start [2.4GB(3.3%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:05<00:00,  1.72s/it]
# [get test_aids] done [3.2GB(3.7%)(+0.829GB)] 5.1545 s
# [save cand_df] start [3.2GB(3.7%)]
# [save cand_df] done [2.8GB(3.5%)(-0.425GB)] 3.4110 s
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_last]] start [1.6GB(2.9%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.436234   ┆ 0.335509   ┆ 0.412382   ┆ 0.39170 ┆ 0.001343 ┆ 0.44665 ┆ 0.484465 ┆ 0.516405 ┆ 0.530364 │
# │ cf_s0 ┆            ┆            ┆            ┆ 5       ┆          ┆ 7       ┆          ┆          ┆          │
# │ _t0_a ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ pTrue ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _tdTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_tr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ Fa... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_last]] done [1.1GB(2.7%)(-0.474GB)] 8.7426 s
# [load] start [1.0GB(2.6%)]
# [load] done [2.1GB(3.2%)(+1.069GB)] 0.8767 s
# [get test_aids] start [2.1GB(3.2%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  3.21s/it]
# [get test_aids] done [3.7GB(3.9%)(+1.585GB)] 9.6171 s
# [save cand_df] start [3.7GB(3.9%)]
# [save cand_df] done [3.3GB(3.7%)(-0.432GB)] 3.4057 s
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_count]] start [1.9GB(3.1%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.210788   ┆ 0.225444   ┆ 0.41522    ┆ 0.33784 ┆ 0.001343 ┆ 0.40855 ┆ 0.456062 ┆ 0.517215 ┆ 0.561138 │
# │ cf_s0 ┆            ┆            ┆            ┆ 4       ┆          ┆ 7       ┆          ┆          ┆          │
# │ _t0_a ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ pTrue ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ _tdTr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ ue_tr ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ Fa... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s0_t0_apTrue_tdTrue_trFalse_iifTrue_fFalse_count]] done [1.6GB(2.9%)(-0.367GB)] 9.1936 s
# [load] start [1.5GB(2.8%)]
# [load] done [1.7GB(2.9%)(+0.194GB)] 0.7223 s
# [get test_aids] start [1.7GB(2.9%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:04<00:00,  1.48s/it]
# [get test_aids] done [2.3GB(3.2%)(+0.638GB)] 4.4375 s
# [save cand_df] start [2.3GB(3.2%)]
# [save cand_df] done [2.0GB(3.1%)(-0.297GB)] 2.8078 s
# [calc score [item_cf_s0_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_sum]] start [1.6GB(2.9%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.267015   ┆ 0.265318   ┆ 0.552109   ┆ 0.43756 ┆ 0.068226 ┆ 0.46692 ┆ 0.482251 ┆ 0.497109 ┆ 0.505009 │
# │ cf_s0 ┆            ┆            ┆            ┆ 2       ┆          ┆ 2       ┆          ┆          ┆          │
# │ _t12_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ apTru ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ e_tdT ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ rue_t ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ rF... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s0_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_sum]] done [1.3GB(2.7%)(-0.359GB)] 8.0128 s
# [load] start [1.2GB(2.7%)]
# [load] done [1.4GB(2.8%)(+0.209GB)] 0.2952 s
# [get test_aids] start [1.4GB(2.8%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:04<00:00,  1.55s/it]
# [get test_aids] done [2.1GB(3.2%)(+0.704GB)] 4.6387 s
# [save cand_df] start [2.1GB(3.2%)]
# [save cand_df] done [1.9GB(3.0%)(-0.293GB)] 2.8075 s
# [calc score [item_cf_s0_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_mean]] start [1.5GB(2.8%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.254948   ┆ 0.243134   ┆ 0.388885   ┆ 0.33176 ┆ 0.068226 ┆ 0.38372 ┆ 0.419205 ┆ 0.454179 ┆ 0.471538 │
# │ cf_s0 ┆            ┆            ┆            ┆ 6       ┆          ┆         ┆          ┆          ┆          │
# │ _t12_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ apTru ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ e_tdT ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ rue_t ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ rF... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s0_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_mean]] done [1.2GB(2.7%)(-0.299GB)] 8.0580 s
# [load] start [1.1GB(2.7%)]
# [load] done [1.3GB(2.8%)(+0.201GB)] 0.2902 s
# [get test_aids] start [1.3GB(2.8%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:04<00:00,  1.59s/it]
# [get test_aids] done [2.1GB(3.2%)(+0.805GB)] 4.7698 s
# [save cand_df] start [2.1GB(3.2%)]
# [save cand_df] done [1.8GB(3.0%)(-0.293GB)] 2.7241 s
# [calc score [item_cf_s0_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_max]] start [1.5GB(2.8%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.264331   ┆ 0.26029    ┆ 0.495611   ┆ 0.40188 ┆ 0.068226 ┆ 0.44791 ┆ 0.473797 ┆ 0.493158 ┆ 0.502311 │
# │ cf_s0 ┆            ┆            ┆            ┆ 6       ┆          ┆ 8       ┆          ┆          ┆          │
# │ _t12_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ apTru ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ e_tdT ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ rue_t ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ rF... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s0_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_max]] done [1.2GB(2.7%)(-0.302GB)] 8.0976 s
# [load] start [1.1GB(2.7%)]
# [load] done [1.3GB(2.8%)(+0.209GB)] 0.2960 s
# [get test_aids] start [1.3GB(2.8%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:02<00:00,  1.07it/s]
# [get test_aids] done [1.8GB(3.0%)(+0.473GB)] 2.7952 s
# [save cand_df] start [1.8GB(3.0%)]
# [save cand_df] done [1.6GB(2.9%)(-0.200GB)] 1.9843 s
# [calc score [item_cf_s0_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_last]] start [1.3GB(2.8%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ item_ ┆ 0.232588   ┆ 0.239889   ┆ 0.451257   ┆ 0.36598 ┆ 0.107503 ┆ 0.40784 ┆ 0.426973 ┆ 0.441531 ┆ 0.448573 │
# │ cf_s0 ┆            ┆            ┆            ┆         ┆          ┆ 6       ┆          ┆          ┆          │
# │ _t12_ ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ apTru ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ e_tdT ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ rue_t ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# │ rF... ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [item_cf_s0_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_last]] done [1.0GB(2.6%)(-0.353GB)] 6.4515 s
# [load] start [0.9GB(2.6%)]
# [load] done [1.1GB(2.7%)(+0.213GB)] 0.2960 s
# [get test_aids] start [1.1GB(2.7%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:04<00:00,  1.55s/it]
# [get test_aids] done [2.3GB(3.2%)(+1.138GB)] 4.6463 s
# [save cand_df] start [2.3GB(3.2%)]
# [save cand_df] done [2.0GB(3.1%)(-0.286GB)] 2.2750 s
# [calc score [item_cf_s0_t12_apTrue_tdTrue_trFalse_iifTrue_fFalse_count]] start [1.6GB(2.9%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ...
# │ 12899771 ┆ 1824869 ┆ 3.4046e-7         ┆ 4                ┆ 4                │
# │ 12899771 ┆ 816971  ┆ 2.8570e-7         ┆ 5                ┆ 5                │
# └──────────┴─────────┴───────────────────┴──────────────────┴──────────────────┘
# item_cf_s012_t012_apTrue_tdTrue_trTrue_iifTrue_fTrue_count
# shape: (5, 5)
# ┌──────────┬─────────┬───────────────────┬──────────────────┬──────────────────┐
# │ session  ┆ aid     ┆ item_cf_s012_t012 ┆ item_cf_s012_t01 ┆ item_cf_s012_t01 │
# │ ---      ┆ ---     ┆ _apTrue_tdTrue_.. ┆ 2_apTrue_tdTrue_ ┆ 2_apTrue_tdTrue_ │
# │ i32      ┆ i32     ┆ .                 ┆ ...              ┆ ...              │
# │          ┆         ┆ ---               ┆ ---              ┆ ---              │
# │          ┆         ┆ f32               ┆ i16              ┆ i16              │
# ╞══════════╪═════════╪═══════════════════╪══════════════════╪══════════════════╡
# │ 12899771 ┆ 1481491 ┆ 1.0               ┆ 1                ┆ 1                │
# │ 12899771 ┆ 1160655 ┆ 1.0               ┆ 2                ┆ 1                │
# │ 12899771 ┆ 579303  ┆ 1.0               ┆ 3                ┆ 1                │
# │ 12899771 ┆ 487374  ┆ 1.0               ┆ 4                ┆ 1                │
# │ 12899771 ┆ 425672  ┆ 1.0               ┆ 5                ┆ 1                │
# └──────────┴─────────┴───────────────────┴──────────────────┴──────────────────┘
# item_cf_s12_t012_apTrue_tdTrue_trTrue_iifTrue_fTrue_sum
# shape: (5, 5)
# ┌──────────┬─────────┬───────────────────┬──────────────────┬──────────────────┐
# │ session  ┆ aid     ┆ item_cf_s12_t012_ ┆ item_cf_s12_t012 ┆ item_cf_s12_t012 │
# │ ---      ┆ ---     ┆ apTrue_tdTrue_t.. ┆ _apTrue_tdTrue_t ┆ _apTrue_tdTrue_t │
# │ i32      ┆ i32     ┆ .                 ┆ ...              ┆ ...              │
# │          ┆         ┆ ---               ┆ ---              ┆ ---              │
# │          ┆         ┆ f32               ┆ i16              ┆ i16              │
# ╞══════════╪═════════╪═══════════════════╪══════════════════╪══════════════════╡
# │ 12899478 ┆ 1059174 ┆ 9.6074e-7         ┆ 1                ┆ 1                │
# │ 12899478 ┆ 590119  ┆ 6.2559e-7         ┆ 2                ┆ 2                │
# │ 12899478 ┆ 1506064 ┆ 5.3444e-7         ┆ 3                ┆ 3                │
# │ 12899478 ┆ 846106  ┆ 4.2271e-7         ┆ 4                ┆ 4                │
# │ 12899478 ┆ 780139  ┆ 3.1156e-7         ┆ 5                ┆ 5                │
# └──────────┴─────────┴───────────────────┴──────────────────┴──────────────────┘
# item_cf_s12_t012_apTrue_tdTrue_trTrue_iifTrue_fTrue_last
# shape: (5, 5)
# ┌──────────┬─────────┬───────────────────┬──────────────────┬──────────────────┐
# │ session  ┆ aid     ┆ item_cf_s12_t012_ ┆ item_cf_s12_t012 ┆ item_cf_s12_t012 │
# │ ---      ┆ ---     ┆ apTrue_tdTrue_t.. ┆ _apTrue_tdTrue_t ┆ _apTrue_tdTrue_t │
# │ i32      ┆ i32     ┆ .                 ┆ ...              ┆ ...              │
# │          ┆         ┆ ---               ┆ ---              ┆ ---              │
# │          ┆         ┆ f32               ┆ i16              ┆ i16              │
# ╞══════════╪═════════╪═══════════════════╪══════════════════╪══════════════════╡
# │ 12899478 ┆ 1059174 ┆ 4.8037e-7         ┆ 1                ┆ 1                │
# │ 12899478 ┆ 590119  ┆ 3.1279e-7         ┆ 2                ┆ 2                │
# │ 12899478 ┆ 1506064 ┆ 2.6722e-7         ┆ 3                ┆ 3                │
# │ 12899478 ┆ 846106  ┆ 2.1136e-7         ┆ 4                ┆ 4                │
# │ 12899478 ┆ 780139  ┆ 1.5578e-7         ┆ 5                ┆ 5                │
# └──────────┴─────────┴───────────────────┴──────────────────┴──────────────────┘
# item_cf_s12_t012_apTrue_tdTrue_trTrue_iifTrue_fTrue_count
# shape: (5, 5)
# ┌──────────┬────────┬───────────────────┬───────────────────┬──────────────────┐
# │ session  ┆ aid    ┆ item_cf_s12_t012_ ┆ item_cf_s12_t012_ ┆ item_cf_s12_t012 │
# │ ---      ┆ ---    ┆ apTrue_tdTrue_t.. ┆ apTrue_tdTrue_t.. ┆ _apTrue_tdTrue_t │
# │ i32      ┆ i32    ┆ .                 ┆ .                 ┆ ...              │
# │          ┆        ┆ ---               ┆ ---               ┆ ---              │
# │          ┆        ┆ f32               ┆ i16               ┆ i16              │
# ╞══════════╪════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ 12899478 ┆ 500274 ┆ 2.0               ┆ 1                 ┆ 1                │
# │ 12899478 ┆ 269021 ┆ 2.0               ┆ 2                 ┆ 1                │
# │ 12899478 ┆ 164613 ┆ 2.0               ┆ 3                 ┆ 1                │
# │ 12899478 ┆ 680005 ┆ 2.0               ┆ 4                 ┆ 1                │
# │ 12899478 ┆ 895975 ┆ 2.0               ┆ 5                 ┆ 1                │
# └──────────┴────────┴───────────────────┴───────────────────┴──────────────────┘
# item_cf_s012_t012_apFalse_tdTrue_trTrue_iifTrue_fFalse_sum
# shape: (5, 5)
# ┌──────────┬─────────┬───────────────────┬──────────────────┬──────────────────┐
# │ session  ┆ aid     ┆ item_cf_s012_t012 ┆ item_cf_s012_t01 ┆ item_cf_s012_t01 │
# │ ---      ┆ ---     ┆ _apFalse_tdTrue.. ┆ 2_apFalse_tdTrue ┆ 2_apFalse_tdTrue │
# │ i32      ┆ i32     ┆ .                 ┆ ...              ┆ ...              │
# │          ┆         ┆ ---               ┆ ---              ┆ ---              │
# │          ┆         ┆ f32               ┆ i16              ┆ i16              │
# ╞══════════╪═════════╪═══════════════════╪══════════════════╪══════════════════╡
# │ 12899771 ┆ 1160655 ┆ 1.442754          ┆ 1                ┆ 1                │
# │ 12899771 ┆ 215084  ┆ 0.000011          ┆ 2                ┆ 2                │
# │ 12899771 ┆ 1734475 ┆ 0.000007          ┆ 3                ┆ 3                │
# │ 12899771 ┆ 1264763 ┆ 0.000007          ┆ 4                ┆ 4                │
# │ 12899771 ┆ 1824869 ┆ 0.000007          ┆ 5                ┆ 5                │
# └──────────┴─────────┴───────────────────┴──────────────────┴──────────────────┘
# item_cf_s012_t012_apFalse_tdTrue_trTrue_iifTrue_fFalse_last
# shape: (5, 5)
# ┌──────────┬─────────┬───────────────────┬──────────────────┬──────────────────┐
# │ session  ┆ aid     ┆ item_cf_s012_t012 ┆ item_cf_s012_t01 ┆ item_cf_s012_t01 │
# │ ---      ┆ ---     ┆ _apFalse_tdTrue.. ┆ 2_apFalse_tdTrue ┆ 2_apFalse_tdTrue │
# │ i32      ┆ i32     ┆ .                 ┆ ...              ┆ ...              │
# │          ┆         ┆ ---               ┆ ---              ┆ ---              │
# │          ┆         ┆ f32               ┆ i16              ┆ i16              │
# ╞══════════╪═════════╪═══════════════════╪══════════════════╪══════════════════╡
# │ 12899771 ┆ 1160655 ┆ 1.442754          ┆ 1                ┆ 1                │
# │ 12899771 ┆ 215084  ┆ 0.000011          ┆ 2                ┆ 2                │
# │ 12899771 ┆ 1734475 ┆ 0.000007          ┆ 3                ┆ 3                │
# │ 12899771 ┆ 1264763 ┆ 0.000007          ┆ 4                ┆ 4                │
# │ 12899771 ┆ 1824869 ┆ 0.000007          ┆ 5                ┆ 5                │
# └──────────┴─────────┴───────────────────┴──────────────────┴──────────────────┘
# item_cf_s012_t012_apFalse_tdTrue_trTrue_iifTrue_fFalse_count
# shape: (5, 5)
# ┌──────────┬─────────┬───────────────────┬──────────────────┬──────────────────┐
# │ session  ┆ aid     ┆ item_cf_s012_t012 ┆ item_cf_s012_t01 ┆ item_cf_s012_t01 │
# │ ---      ┆ ---     ┆ _apFalse_tdTrue.. ┆ 2_apFalse_tdTrue ┆ 2_apFalse_tdTrue │
# │ i32      ┆ i32     ┆ .                 ┆ ...              ┆ ...              │
# │          ┆         ┆ ---               ┆ ---              ┆ ---              │
# │          ┆         ┆ f32               ┆ i16              ┆ i16              │
# ╞══════════╪═════════╪═══════════════════╪══════════════════╪══════════════════╡
# │ 12899771 ┆ 1558720 ┆ 1.0               ┆ 1                ┆ 1                │
# │ 12899771 ┆ 1429022 ┆ 1.0               ┆ 2                ┆ 1                │
# │ 12899771 ┆ 762611  ┆ 1.0               ┆ 3                ┆ 1                │
# │ 12899771 ┆ 1559401 ┆ 1.0               ┆ 4                ┆ 1                │
# │ 12899771 ┆ 215000  ┆ 1.0               ┆ 5                ┆ 1                │
# └──────────┴─────────┴───────────────────┴──────────────────┴──────────────────┘
# item_mf_last
# shape: (5, 6)
# ┌──────────┬─────────┬──────────┬───────────────┬───────────────┬──────────────┐
# │ session  ┆ aid     ┆ score    ┆ item_mf_last_ ┆ item_mf_last_ ┆ item_mf_last │
# │ ---      ┆ ---     ┆ ---      ┆ score         ┆ score_rank    ┆ _score_min_r │
# │ i32      ┆ i32     ┆ f64      ┆ ---           ┆ ---           ┆ ank          │
# │          ┆         ┆          ┆ f32           ┆ i16           ┆ ---          │
# │          ┆         ┆          ┆               ┆               ┆ i16          │
# ╞══════════╪═════════╪══════════╪═══════════════╪═══════════════╪══════════════╡
# │ 12899771 ┆ 1160655 ┆ 1.0      ┆ 1.0           ┆ 1             ┆ 1            │
# │ 12899771 ┆ 1824869 ┆ 0.663472 ┆ 0.663472      ┆ 2             ┆ 2            │
# │ 12899771 ┆ 80519   ┆ 0.657649 ┆ 0.657649      ┆ 3             ┆ 3            │
# │ 12899771 ┆ 1825743 ┆ 0.576232 ┆ 0.576232      ┆ 4             ┆ 4            │
# │ 12899771 ┆ 215084  ┆ 0.561732 ┆ 0.561732      ┆ 5             ┆ 5            │
# └──────────┴─────────┴──────────┴───────────────┴───────────────┴──────────────┘
# item_mf_seq
# shape: (5, 6)
# ┌──────────┬─────────┬──────────┬───────────────┬───────────────┬──────────────┐
# │ session  ┆ aid     ┆ score    ┆ item_mf_seq_s ┆ item_mf_seq_s ┆ item_mf_seq_ │
# │ ---      ┆ ---     ┆ ---      ┆ core          ┆ core_rank     ┆ score_min_ra │
# │ i32      ┆ i32     ┆ f64      ┆ ---           ┆ ---           ┆ nk           │
# │          ┆         ┆          ┆ f32           ┆ i16           ┆ ---          │
# │          ┆         ┆          ┆               ┆               ┆ i16          │
# ╞══════════╪═════════╪══════════╪═══════════════╪═══════════════╪══════════════╡
# │ 12899771 ┆ 1160655 ┆ 1.0      ┆ 1.0           ┆ 1             ┆ 1            │
# │ 12899771 ┆ 1824869 ┆ 0.663472 ┆ 0.663472      ┆ 2             ┆ 2            │
# │ 12899771 ┆ 80519   ┆ 0.657649 ┆ 0.657649      ┆ 3             ┆ 3            │
# │ 12899771 ┆ 1825743 ┆ 0.576232 ┆ 0.576232      ┆ 4             ┆ 4            │
# │ 12899771 ┆ 215084  ┆ 0.561732 ┆ 0.561732      ┆ 5             ┆ 5            │
# └──────────┴─────────┴──────────┴───────────────┴───────────────┴──────────────┘
# user_mf
# shape: (5, 6)
# ┌──────────┬─────────┬──────────┬───────────────┬───────────────┬──────────────┐
# │ session  ┆ aid     ┆ score    ┆ user_mf_score ┆ user_mf_score ┆ user_mf_scor │
# │ ---      ┆ ---     ┆ ---      ┆ ---           ┆ _rank         ┆ e_min_rank   │
# │ i32      ┆ i32     ┆ f64      ┆ f32           ┆ ---           ┆ ---          │
# │          ┆         ┆          ┆               ┆ i16           ┆ i16          │
# ╞══════════╪═════════╪══════════╪═══════════════╪═══════════════╪══════════════╡
# │ 12899771 ┆ 1160655 ┆ 0.935756 ┆ 0.935756      ┆ 1             ┆ 1            │
# │ 12899771 ┆ 1824869 ┆ 0.689053 ┆ 0.689053      ┆ 2             ┆ 2            │
# │ 12899771 ┆ 1357281 ┆ 0.681616 ┆ 0.681616      ┆ 3             ┆ 3            │
# │ 12899771 ┆ 753450  ┆ 0.572916 ┆ 0.572916      ┆ 4             ┆ 4            │
# │ 12899771 ┆ 215084  ┆ 0.571398 ┆ 0.571398      ┆ 5             ┆ 5            │
# └──────────┴─────────┴──────────┴───────────────┴───────────────┴──────────────┘
# item2vec
# shape: (5, 6)
# ┌──────────┬─────────┬──────────┬───────────────┬───────────────┬──────────────┐
# │ session  ┆ aid     ┆ score    ┆ item2vec_scor ┆ item2vec_scor ┆ item2vec_sco │
# │ ---      ┆ ---     ┆ ---      ┆ e             ┆ e_rank        ┆ re_min_rank  │
# │ i32      ┆ i32     ┆ f64      ┆ ---           ┆ ---           ┆ ---          │
# │          ┆         ┆          ┆ f32           ┆ i16           ┆ i16          │
# ╞══════════╪═════════╪══════════╪═══════════════╪═══════════════╪══════════════╡
# │ 12899771 ┆ 1160655 ┆ 1.0      ┆ 1.0           ┆ 1             ┆ 1            │
# │ 12899771 ┆ 753450  ┆ 0.983584 ┆ 0.983584      ┆ 2             ┆ 2            │
# │ 12899771 ┆ 1592239 ┆ 0.976759 ┆ 0.976759      ┆ 3             ┆ 3            │
# │ 12899771 ┆ 834831  ┆ 0.975479 ┆ 0.975479      ┆ 4             ┆ 4            │
# │ 12899771 ┆ 215084  ┆ 0.974009 ┆ 0.974009      ┆ 5             ┆ 5            │
# └──────────┴─────────┴──────────┴───────────────┴───────────────┴──────────────┘
# item2vec
# shape: (5, 6)
# ┌──────────┬─────────┬──────────┬───────────────┬───────────────┬──────────────┐
# │ session  ┆ aid     ┆ score    ┆ item2vec_scor ┆ item2vec_scor ┆ item2vec_sco │
# │ ---      ┆ ---     ┆ ---      ┆ e             ┆ e_rank        ┆ re_min_rank  │
# │ i32      ┆ i32     ┆ f64      ┆ ---           ┆ ---           ┆ ---          │
# │          ┆         ┆          ┆ f32           ┆ i16           ┆ i16          │
# ╞══════════╪═════════╪══════════╪═══════════════╪═══════════════╪══════════════╡
# │ 12899771 ┆ 1160655 ┆ 1.0      ┆ 1.0           ┆ 1             ┆ 1            │
# │ 12899771 ┆ 753450  ┆ 0.983584 ┆ 0.983584      ┆ 2             ┆ 2            │
# │ 12899771 ┆ 1592239 ┆ 0.976759 ┆ 0.976759      ┆ 3             ┆ 3            │
# │ 12899771 ┆ 834831  ┆ 0.975479 ┆ 0.975479      ┆ 4             ┆ 4            │
# │ 12899771 ┆ 215084  ┆ 0.974009 ┆ 0.974009      ┆ 5             ┆ 5            │
# └──────────┴─────────┴──────────┴───────────────┴───────────────┴──────────────┘
# [get session aid list] start [2.3GB(3.2%)]
# 100%|████████████████████████████| 4/4 [00:21<00:00,  5.48s/it, mem=5.2GB(4.8%)]
# [get session aid list] done [5.2GB(4.8%)(+2.928GB)] 21.9140 s
# [add target cols] start [5.2GB(4.8%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:02<00:00,  1.26it/s]
# [add target cols] done [4.5GB(4.5%)(-0.722GB)] 2.3811 s
# [add no_target cols] start [4.5GB(4.5%)]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  3.20it/s]
# [add no_target cols] done [3.8GB(4.1%)(-0.752GB)] 0.9369 s
# [drop no target sessions] start [3.8GB(4.1%)]
# before dropping: (22163340, 8)
# after dropping: (14613930, 8)
# [drop no target sessions] done [3.7GB(4.1%)(-0.093GB)] 0.0666 s
# [split kfold] start [3.7GB(4.1%)]
# [split kfold] done [3.7GB(4.1%)(-0.017GB)] 2.0852 s
# [join selected] start [3.7GB(4.1%)]
# 100%|██████████████████████████| 37/37 [00:30<00:00,  1.20it/s, mem=4.3GB(4.3%)]
# [join selected] done [4.3GB(4.3%)(+0.607GB)] 30.9086 s
# [join scores] start [4.3GB(4.3%)]
# 100%|██████████████████████████| 37/37 [00:47<00:00,  1.27s/it, mem=8.4GB(6.3%)]
# [join scores] done [8.4GB(6.3%)(+4.103GB)] 47.1608 s
# [add cand_feature_selected_num] start [8.4GB(6.3%)]
# [add cand_feature_selected_num] done [8.4GB(6.3%)(+0.043GB)] 2.0334 s
# [add cand_feature_score] start [8.4GB(6.3%)]
# [add cand_feature_score] done [8.3GB(6.3%)(-0.071GB)] 1.1466 s
# [save cand_df] start [8.3GB(6.3%)]
# [save cand_df] done [3.4GB(4.5%)(-4.902GB)] 42.2153 s
# [calc score [cand_merger]] start [3.4GB(4.5%)]
# shape: (1, 10)
# ┌───────┬────────────┬────────────┬────────────┬─────────┬──────────┬─────────┬──────────┬──────────┬──────────┐
# │ cg_na ┆ recall_cli ┆ recall_car ┆ recall_ord ┆ recall@ ┆ null_rat ┆ recall@ ┆ recall@1 ┆ recall@2 ┆ recall@3 │
# │ me    ┆ ck@20      ┆ t@20       ┆ er@20      ┆ 20      ┆ io       ┆ 50      ┆ 00       ┆ 00       ┆ 00       │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---      ┆ ---     ┆ ---      ┆ ---      ┆ ---      │
# │ str   ┆ f64        ┆ f64        ┆ f64        ┆ f64     ┆ f64      ┆ f64     ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪════════════╪════════════╪═════════╪══════════╪═════════╪══════════╪══════════╪══════════╡
# │ cand_ ┆ 0.468432   ┆ 0.380555   ┆ 0.629529   ┆ 0.53872 ┆ 0.317314 ┆ 0.57392 ┆ 0.593918 ┆ 0.610669 ┆ 0.617862 │
# │ merge ┆            ┆            ┆            ┆ 7       ┆          ┆ 9       ┆          ┆          ┆          │
# │ r     ┆            ┆            ┆            ┆         ┆          ┆         ┆          ┆          ┆          │
# └───────┴────────────┴────────────┴────────────┴─────────┴──────────┴─────────┴──────────┴──────────┴──────────┘
# [calc score [cand_merger]] done [3.2GB(3.8%)(-0.208GB)] 11.9021 s

# %%
# !./bin/003_feature_engineering.sh exp001_dev
# Out:
# + EXP=exp001_dev
# + PYTHONPATH=.
# + python kaggle_otto2/feature/main.py --exp exp001_dev
# [create features] start [0.4GB(2.2%)]
#   0%|                                                    | 0/13 [00:00<?, ?it/s][ItemInterNum] start [0.4GB(2.2%)]
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:00<00:00, 11.64it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  3.34it/s]
# [ItemInterNum] done [1.1GB(2.6%)(+0.778GB)] 2.7798 s
#   8%|███▍                                        | 1/13 [00:02<00:33,  2.78s/it][ItemInterRank] start [1.1GB(2.6%)]
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  25%|███████████▎                                 | 1/4 [00:00<00:00,  7.00it/s]
#  50%|██████████████████████▌                      | 2/4 [00:00<00:00,  5.90it/s]
#  75%|█████████████████████████████████▊           | 3/4 [00:01<00:00,  2.03it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:02<00:00,  1.61it/s]
# [ItemInterRank] done [1.5GB(2.8%)(+0.381GB)] 4.3230 s
#  15%|██████▊                                     | 2/13 [00:07<00:40,  3.69s/it][ItemInterTsStats] start [1.5GB(2.8%)]
# [ItemInterTsStats] done [1.4GB(2.8%)(-0.128GB)] 1.8080 s
#  23%|██████████▏                                 | 3/13 [00:08<00:28,  2.83s/it][ItemMultiInterProb] start [1.4GB(2.8%)]
# [ItemMultiInterProb] done [1.5GB(2.9%)(+0.086GB)] 2.5251 s
#  31%|█████████████▌                              | 4/13 [00:11<00:24,  2.71s/it][ItemTypeToTypeProb] start [1.5GB(2.9%)]
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  25%|███████████▎                                 | 1/4 [00:00<00:01,  1.77it/s]
#  50%|██████████████████████▌                      | 2/4 [00:01<00:01,  1.81it/s]
#  75%|█████████████████████████████████▊           | 3/4 [00:01<00:00,  2.04it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  2.25it/s]
# [ItemTypeToTypeProb] done [1.6GB(3.0%)(+0.084GB)] 2.7235 s
#  38%|████████████████▉                           | 5/13 [00:14<00:21,  2.72s/it][UserInterDow] start [1.6GB(3.0%)]
# [UserInterDow] done [1.5GB(3.0%)(-0.049GB)] 0.7345 s
#  46%|████████████████████▎                       | 6/13 [00:14<00:14,  2.04s/it][UserInterNum] start [1.5GB(3.0%)]
# [UserInterNum] done [1.5GB(3.0%)(-0.008GB)] 0.0919 s
# [UserInterTsDiff] start [1.5GB(3.0%)]
# [UserInterTsDiff] done [1.3GB(2.9%)(-0.139GB)] 0.3591 s
#  62%|███████████████████████████                 | 8/13 [00:15<00:05,  1.15s/it][UserInterTsHour] start [1.3GB(2.9%)]
# [UserInterTsHour] done [1.4GB(2.9%)(+0.038GB)] 0.2180 s
#  69%|██████████████████████████████▍             | 9/13 [00:15<00:03,  1.10it/s][UserInterTsStats] start [1.4GB(2.9%)]
# [UserInterTsStats] done [1.3GB(2.9%)(-0.037GB)] 0.1288 s
#  77%|█████████████████████████████████          | 10/13 [00:15<00:02,  1.44it/s][UserItemFirstInterRank] start [1.3GB(2.9%)]
# [UserItemFirstInterRank] done [1.3GB(2.9%)(-0.038GB)] 0.4287 s
#  85%|████████████████████████████████████▍      | 11/13 [00:16<00:01,  1.61it/s][UserItemIsFirstInter] start [1.3GB(2.9%)]
# [UserItemIsFirstInter] done [1.3GB(2.9%)(-0.051GB)] 0.5827 s
#  92%|███████████████████████████████████████▋   | 12/13 [00:16<00:00,  1.64it/s][UserTsDiff] start [1.3GB(2.9%)]
# [UserTsDiff] done [1.3GB(2.9%)(+0.014GB)] 0.1178 s
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.29s/it]
# [create features] done [1.3GB(2.9%)(+0.896GB)] 16.8324 s
# [merge features] start [1.3GB(2.9%)]
# [merge] start [1.3GB(2.9%)]
# [merge features] start [1.3GB(2.9%)]
# 100%|███████████████████████████████████████████| 13/13 [00:01<00:00,  8.71it/s]
# [merge features] done [1.8GB(3.1%)(+0.501GB)] 1.4929 s
# [load cand_merger cand_df] start [1.8GB(3.1%)]
# [load cand_merger cand_df] done [6.6GB(5.5%)(+4.784GB)] 1.4146 s
# [merge features into cand_df] start [6.6GB(5.5%)]
# ['aid', 'session', 'session,aid']
# 100%|███████████████████████████| 3/3 [00:01<00:00,  2.03it/s, mem=12.9GB(8.6%)]
# [merge features into cand_df] done [12.9GB(8.6%)(+6.382GB)] 1.4774 s
# [fillna and convert dtypes] start [12.9GB(8.6%)]
# 100%|███████████████████████████████████████████| 13/13 [00:02<00:00,  4.80it/s]
# [fillna and convert dtypes] done [12.9GB(8.6%)(-0.007GB)] 2.7114 s
# [save cand_df] start [12.9GB(8.6%)]
# [save cand_df] done [12.9GB(8.6%)(-0.000GB)] 76.8182 s
# [merge] done [12.9GB(8.6%)(+11.659GB)] 83.9163 s
# [merge features] done [1.8GB(3.2%)(+0.580GB)] 84.0911 s
# [negative sampling] start [1.8GB(3.2%)]
# [neg sampling] start [1.8GB(3.2%)]
# [load] start [1.8GB(3.2%)]
# [load] done [12.9GB(8.6%)(+11.008GB)] 4.2592 s
# [neg sample] start [12.9GB(8.6%)]
# before negative sampling:  (14613930, 291)

# %%
# !./bin/004_train_ranker.sh exp001_dev lgbm
